# %%
import matplotlib.pyplot as plt
import numpy as np
from cnet_riff_dataset import CnetRiffDataset, preprocess_batch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/4l/6kfdr46j65z_dzyx1kkf75300000gn/T/ipykernel_11647/441846027.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 from cnet_riff_dataset import CnetRiffDataset, preprocess_batch
#
# ~/Desktop/Stanford/_Win2023/EE 269/Project/mel-generator/mel-generator/playground/cnet_riff_dataset.py in <module>
#       8 # for spectrum generation
#       9 from spec_segment_gen import generate_specs_batch, segment_audio, write_wav_file
# ---> 10 from external import riffusion_tools
#      11 import spleeter_utils
#      12
#
# ImportError: cannot import name 'riffusion_tools' from 'external' (../riffusion-reference/riffusion/external/__init__.py)

# %%
# parameters

# names of files to segment
audio_files = ['pop.00000.wav', 'pop.00003.wav']
manual_prompts = ['']
# folder where raw audio files are located in
audio_files_dir = "../pop-data/"
# where to output everything to
dataset_dir = "test_dataset"

# generate the training data into directory from audio files
generate_training_data_from_audio(audio_files, 
                                  audio_files_dir, 
                                  dataset_dir, 
                                  manual_prompts=None, 
                                  verbose=False)

# collect all training data into training object
train_dataset = CnetRiffDataset(dataset_dir)
# Out:
# ../riffusion-reference/riffusion/spectrogram_image_converter.py:21: UserWarning: WARNING: cuda is not available, using cpu instead.
#   self.converter = SpectrogramConverter(params=params, device=device)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:02<00:00,  8.56it/s]

# %%
# show sample contents if desired
print("Sample contents of dataset")
item = train_dataset[0]
plt.imshow((item['jpg'] + 1 )/ 2)
plt.title("Target spectrogram")
plt.figure()
plt.imshow(item['hint'])
plt.title("Source (canny edges)")
print("prompt:", item['txt'])
# Out:
# Sample contents of dataset
# prompt: dummy prompt

# %%
# names of files to segment
audio_files = ['pop.00000.wav', 'pop.00003.wav']
# folder where raw audio files are located in
audio_files_dir = "../pop-data/"
# where to output everything to
dataset_dir = "test_dataset_full_pipeline"

preprocess_batch(audio_files = audio_files,
                 audio_files_dir = audio_files_dir,
                 output_dir = dataset_dir,
                 fs=22050,
                 verbose=True,
                 save_wav=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4l/6kfdr46j65z_dzyx1kkf75300000gn/T/ipykernel_11647/2980686952.py in <module>
#       6 dataset_dir = "test_dataset_full_pipeline"
#       7
# ----> 8 preprocess_batch(audio_files = audio_files,
#       9                  audio_files_dir = audio_files_dir,
#      10                  output_dir = dataset_dir,
#
# NameError: name 'preprocess_batch' is not defined
